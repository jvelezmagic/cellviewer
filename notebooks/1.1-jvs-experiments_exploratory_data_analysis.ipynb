# %% [markdown]
# # Experiments Exploratory Data Analysis

# %% [markdown]
# ## Simple setup
# To use the `src` module inside of the notebooks:

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Imports

# %%
import janitor
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy.stats as ss

import src # Load custom functions.

# %% [markdown]
# ## Load data

# %%
experiments_file = src.data_processed_dir("experiments_data.csv")

# %%
df = pd.read_csv(filepath_or_buffer=experiments_file)
df.head()
# Out:
#    lineage_id   track_id  cell_id  mother_id  frame                roi_id  \
# 0         0.0  10.8-34.0     10.8       10.8      0  roi_f10_n8_x129_y214
# 1         0.0  10.8-34.0     11.6       10.8      1  roi_f11_n6_x126_y216
# 2         0.0  10.8-34.0     12.8       10.8      2  roi_f12_n8_x122_y225
# 3         0.0  10.8-34.0     13.8       10.8      3  roi_f13_n8_x124_y224
# 4         0.0  10.8-34.0     14.5       10.8      4  roi_f14_n5_x124_y220
#
#       length  division  dead      gfp    dsred  \
# 0  25.849682       0.0   0.0  120.110  108.394
# 1  41.415207       1.0   0.0  120.289  108.422
# 2  19.348009       0.0   0.0  119.765  107.959
# 3  26.301427       0.0   0.0  119.771  108.061
# 4  26.475045       0.0   0.0  119.718  107.977
#
#                            file_name_id        experiment_id
# 0  MGGT-AMP-Pulse_xy01_lineages_all.csv  chromosome_lineages
# 1  MGGT-AMP-Pulse_xy01_lineages_all.csv  chromosome_lineages
# 2  MGGT-AMP-Pulse_xy01_lineages_all.csv  chromosome_lineages
# 3  MGGT-AMP-Pulse_xy01_lineages_all.csv  chromosome_lineages
# 4  MGGT-AMP-Pulse_xy01_lineages_all.csv  chromosome_lineages

# %% [markdown]
# ## Transform data

# %%
tidy_df = df.pivot_longer(column_names=["length", "gfp", "dsred"])
tidy_df.head()
# Out:
#    lineage_id   track_id  cell_id  mother_id  frame                roi_id  \
# 0         0.0  10.8-34.0     10.8       10.8      0  roi_f10_n8_x129_y214
# 1         0.0  10.8-34.0     11.6       10.8      1  roi_f11_n6_x126_y216
# 2         0.0  10.8-34.0     12.8       10.8      2  roi_f12_n8_x122_y225
# 3         0.0  10.8-34.0     13.8       10.8      3  roi_f13_n8_x124_y224
# 4         0.0  10.8-34.0     14.5       10.8      4  roi_f14_n5_x124_y220
#
#    division  dead                          file_name_id        experiment_id  \
# 0       0.0   0.0  MGGT-AMP-Pulse_xy01_lineages_all.csv  chromosome_lineages
# 1       1.0   0.0  MGGT-AMP-Pulse_xy01_lineages_all.csv  chromosome_lineages
# 2       0.0   0.0  MGGT-AMP-Pulse_xy01_lineages_all.csv  chromosome_lineages
# 3       0.0   0.0  MGGT-AMP-Pulse_xy01_lineages_all.csv  chromosome_lineages
# 4       0.0   0.0  MGGT-AMP-Pulse_xy01_lineages_all.csv  chromosome_lineages
#
#   variable      value
# 0   length  25.849682
# 1   length  41.415207
# 2   length  19.348009
# 3   length  26.301427
# 4   length  26.475045

# %%
stats_df = (
    tidy_df
    .select_columns(["experiment_id", "frame", "variable", "value"])
    .groupby(["experiment_id", "frame", "variable"])
    ["value"]
    .aggregate([
        ("mean", np.mean),
        ("std", np.std),
        ("variation", ss.variation),
        ("skew", ss.skew)
    ])
    .reset_index()
    .pivot_longer(
        column_names=["mean", "std", "variation", "skew"],
        names_to="stat"
    )
)
stats_df.head()
# Out:
#          experiment_id  frame variable  stat       value
# 0  chromosome_lineages      0    dsred  mean  108.088855
# 1  chromosome_lineages      0      gfp  mean  121.478737
# 2  chromosome_lineages      0   length  mean   27.322487
# 3  chromosome_lineages      1    dsred  mean  108.072094
# 4  chromosome_lineages      1      gfp  mean  121.831428

# %% [markdown]
# ## Visualize data

# %% [markdown]
# ### Set plotting defaults

# %%
sns.set_style("whitegrid")

plot_defaults = dict(
    sharey="row",
    sharex=True,
    hue="experiment_id",
    height=5.0,
    aspect=1.0
)

# %% [markdown]
# ### Output directory

# %%
out_dir = src.reports_figures_dir; out_dir().relative_to(src.here())
# Out:
# PosixPath('reports/figures')

# %% [markdown]
# ### Basic observations

# %%
(
    tidy_df
    .experiment_plot(func=sns.boxenplot, **plot_defaults)
    .savefig(out_dir("population_time_overview_boxplot.pdf"))
)

# %%
# (
#     tidy_df
#     .experiment_plot(
#         func=sns.lineplot,
#         row="variable",
#         col=None,
#         **plot_defaults
#     )
#     .savefig(out_dir("population_time_overview_lineplot.pdf"))
# )

# %%
# #  Don't run since it takes a couple of minutes.
# (
#     tidy_df
#     .experiment_plot(
#         func=sns.lineplot,
#         func_kwargs=dict(
#             units="track_id",
#             legend=False,
#             lw=0.5,
#             estimator=None,
#             alpha=1/5
#         ),
#         **plot_defaults
#     )
#     .savefig(out_dir("individual_time_overview_lineplot.pdf"))
# )

# %%
(
    stats_df
    .facet_grid_plot(
        func=sns.lineplot,
        x="frame",
        y="value",
        row="stat",
        col="experiment_id",
        sharey="row",
        height=5.0,
        func_kwargs=dict(
            hue="variable",
            style="variable",
            dashes=False,
            markers=True
        )
    )
    .set_axis_labels("Frame", "Value")
    .savefig(out_dir("basic_stats_time_overview.pdf"))
)
plt.legend();
